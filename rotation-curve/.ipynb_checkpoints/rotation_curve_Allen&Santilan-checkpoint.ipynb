# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.001,100,10000) # kpc units
y = np.linspace(0.001,100,10000)
z = np.linspace(0.001,100,10000)

R = np.sqrt(x**2 + y**2 + z**2) # kpc units

# Central mass
M1 = 606.
b1 = 0.3873

dphi_x1 =  M1*x/(x**2 + y**2 + z**2 +b1**2)**(3/2)
dphi_y1 =  M1*y/(x**2 + y**2 + z**2 +b1**2)**(3/2) 
dphi_z1 =  M1*z/(x**2 + y**2 + z**2 +b1**2)**(3/2) 
dphi1 = np.sqrt((dphi_x1**2 + dphi_y1**2 + dphi_z1**2)) # meters?

ac_1 = - dphi1*100
vel_c1 = np.sqrt(-R*ac_1) # km/s

# %%
# Disk component
M2 = 3690.
a2 = 5.3178
b2 = 0.25

dphi_x2 = M2*x / (x**2 + y**2 + (a2 + np.sqrt(z**2 + b2))**2)**(3/2)
dphi_y2 = M2*y / (x**2 + y**2 + (a2 + np.sqrt(z**2 + b2))**2)**(3/2)
dphi_z2 = M2*(a2*z*1/np.sqrt(z**2 + b2**2) + z) / (x**2 + y**2 + (a2 + np.sqrt(z**2 + b2))**2)**(3/2)
dphi2 = np.sqrt((dphi_x2**2 + dphi_y2**2 + dphi_z2**2)) # meters?

ac_2 = -dphi2*100
vel_c2 = np.sqrt(-R*ac_2) # km/s

# %%
# Halo
M3 = 4615.
a3 = 12.

a = (R/a3)**2.02
b = (R/a3)**1.02
c = R**1.02

term1 = -1.02*M3*a*((1 + b) + b)*(x/R) / (R*(1 + b))**2
term2 = (-M3*x/(R*(a3**2)*(1 + (R/a3)**(1.02)))) * (1.02/(1 + (R/a3)**(1.02)) + (R/a3)**(0.02)) * (R/a3)**0.02
dphi_x3 = term1 + term2
dphi3 = np.sqrt(3*dphi_x3**2)

ac_3 = -dphi3*100
vel_c3 = np.sqrt(-R*ac_3)

# %%
np.sum(np.isnan(vel_c3))

# %%
vel_c3

# %%
v = np.sqrt(-R*(ac_1 + ac_2 + ac_3))

plt.plot(R, vel_c1, color = "purple", label = "Central mass", linestyle = "dashed")
plt.plot(R, vel_c2, color = "blue", label = "Disk", linestyle = "dotted")
plt.plot(R, vel_c3, color = "red", label = "Halo", linestyle = "dashdot")
plt.plot(R, v, color = "k", label = "Total rotation curve")
plt.xlabel("R (kpc)")
plt.ylabel("Circular velocity (km s$^{-1}$)")
plt.xlim(0,100)
plt.ylim(0,350)
plt.legend()
plt.show()

# %%
plt.plot(R, v, color = "k", label = "Total rotation curve")
plt.xlabel("R (kpc)")
plt.ylabel("Circular velocity (km s$^{-1}$)")
plt.xlim(0,70)
plt.ylim(170,270)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.001,100,10000) # kpc units
y = np.linspace(0.001,100,10000)
z = np.zeros(10000)

R = np.sqrt(x**2 + y**2) # kpc units

# Central mass
M1 = 606.
b1 = 0.3873

dphi_x1 =  M1*x/(x**2 + y**2 +b1**2)**(3/2)
dphi_y1 =  M1*y/(x**2 + y**2 + b1**2)**(3/2) 

vel_c1 = np.sqrt(100*(dphi_x1*x + dphi_y1*y)) # km/s

# Disk component
M2 = 3690.
a2 = 5.3178
b2 = 0.25

dphi_x2 = M2*x / (x**2 + y**2 + (a2 + np.sqrt(z**2 + b2))**2)**(3/2)
dphi_y2 = M2*y / (x**2 + y**2 + (a2 + np.sqrt(z**2 + b2))**2)**(3/2)

vel_c2 = np.sqrt(100*(dphi_x2*x + dphi_y2*y)) # km/s

# Halo
M3 = 4615.
a3 = 12.

a = (R/a3)**2.02
b = (R/a3)**1.02
c = R**1.02

term1 = -1.02*M3*(x/R)*a/(R*(1 + b))**2
term2 = -M3/(a3**2) * (R/a3)**0.02 * (1/(1 + b)) * (-1.02/(1 + b) + 1) 
dphi_x3 = (term1 + term2)
dphi_y3 = dphi_x3

vel_c3 = np.sqrt(100*2*(dphi_x3 * x))

# v = np.sqrt(100*((dphi_x1 + dphi_x2 + dphi_x3)*x + (dphi_y1 + dphi_y2 + dphi_y3)*y))
v = vel_c1 + vel_c2 + vel_c3

plt.plot(R, vel_c1, color = "purple", label = "Central mass", linestyle = "dashed")
plt.plot(R, vel_c2, color = "blue", label = "Disk", linestyle = "dotted")
plt.plot(R, vel_c3, color = "red", label = "Halo", linestyle = "dashdot")
plt.plot(R, v, color = "k", label = "Total rotation curve")

plt.xlabel("R (kpc)")
plt.ylabel("Circular velocity (km s$^{-1}$)")
plt.xlim(0,100)
#plt.ylim(0,350)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_28915/3112596672.py:42: RuntimeWarning: invalid value encountered in sqrt
#   vel_c3 = np.sqrt(100*2*(dphi_x3 * x))

# %%
np.sum(np.where(term1>0))
dphi_x3.max()
# Out:
# np.float64(-2.4600101712863047)

# %%
plt.plot(R, v, color = "k", label = "Total rotation curve")
plt.xlabel("R (kpc)")
plt.ylabel("Circular velocity (km s$^{-1}$)")
plt.xlim(0,70)
plt.ylim(170,270)
plt.legend()
plt.show()
